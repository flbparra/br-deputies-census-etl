# %% [markdown]
# # ETL Pipeline: Deputies Spending vs. Census Population 2022
#
# This notebook orchestrates the full ETL flow and provides visualizations for the final analysis.

# %%
import sys
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, display

# Add src directory to path
sys.path.append(os.path.abspath('../src'))

from extract import extract_all
from transform import transform_data
from load import save_processed_data, save_ranking_report, generate_visualizations

# %% [markdown]
# ## 1. Extraction (Async with httpx)
# Fetching data from Chamber of Deputies and IBGE Census APIs.

# %%
df_despesas, df_populacao = extract_all()

# %% [markdown]
# ## 2. Transformation
# Grouping spending by state and calculating cost per capita.

# %%
df_final = transform_data(df_despesas, df_populacao)
df_final.head(10)

# %% [markdown]
# ## 3. Loading & Reporting
# Saving CSV files and generating a ranking chart.

# %%
save_processed_data(df_final, '../data/processed/despesas_censo_uf.csv')
save_ranking_report(df_final, '../data/output/ranking_per_capita.csv')
generate_visualizations(df_final, '../data/output/')

# %% [markdown]
# ## 4. Results Visualization

# %%
display(Image(filename='../data/output/per_capita_ranking_chart.png'))
